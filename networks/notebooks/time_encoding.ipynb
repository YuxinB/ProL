# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
import torch

# %%
sys.path.append("..")
from utils.net import TimeEmbedding, DiscreteTime

# %%
net = DiscreteTime('cpu', 50)

times = torch.arange(0, 100).reshape(-1, 1)
out = net(times)
plt.imshow(out.numpy())
plt.show()

# %%
net = TimeEmbedding('cpu', 50)

times = torch.arange(0, 100).reshape(-1, 1)
out = net(times)
plt.imshow(out.numpy())
plt.show()
